# %%
import pandas as pd
import numpy as np

from bokeh.plotting import figure
from bokeh.tile_providers import get_provider, WIKIMEDIA, CARTODBPOSITRON, STAMEN_TERRAIN, STAMEN_TONER, ESRI_IMAGERY, OSM
from bokeh.io import output_notebook, show

import warnings

warnings.filterwarnings("ignore")

output_notebook()
# Out:
#     <div class="bk-root">
#         <a href="https://bokeh.org" target="_blank" class="bk-logo bk-logo-small bk-logo-notebook"></a>
#         <span id="1002">Loading BokehJS ...</span>
#     </div>

# %%
data = pd.read_csv("../Downloads/hail.csv")

# %%
data.head(2)
# Out:
#        om    yr  mo  dy        date      time  tz  st  stf  stn  ...   elon  \
# 0  649851  2020   1  10  2020-01-10  07:42:00   3  OK   40    0  ... -99.43
# 1  649852  2020   1  10  2020-01-10  08:10:00   3  OK   40    0  ... -99.24
#
#    len  wid  ns  sn  sg   f1  f2  f3  f4
# 0    0    0   0   0   0  129   0   0   0
# 1    0    0   0   0   0   43   0   0   0
#
# [2 rows x 28 columns]

# %%
data.columns
# Out:
# Index(['om', 'yr', 'mo', 'dy', 'date', 'time', 'tz', 'st', 'stf', 'stn', 'mag',
#        'inj', 'fat', 'loss', 'closs', 'slat', 'slon', 'elat', 'elon', 'len',
#        'wid', 'ns', 'sn', 'sg', 'f1', 'f2', 'f3', 'f4'],
#       dtype='object')

# %%
wikimedia = get_provider(WIKIMEDIA)

fig = figure(plot_width=800, plot_height=700,
           x_range=(-16000000, -3000000), y_range=(-6000000, 1000000),
           x_axis_type="mercator", y_axis_type="mercator")

fig.add_tile(wikimedia)


show(fig)
# Out:
#   <div class="bk-root" id="0448766c-37ed-4a78-acd4-2c3afc783446" data-root-id="12785"></div>

# %%
from geopy.exc import GeocoderTimedOut
from geopy.geocoders import Nominatim

# %%
def findGeocode(city):

    try:
          
        geolocator = Nominatim(user_agent="test")
          
        return geolocator.geocode(city)
      
    except GeocoderTimedOut:
          
        return findGeocode(city)    

def convert_city_to_coordinates(data):
    df = pd.DataFrame(data) 

    longitude = []
    latitude = []

    for i in (df["City"]):

        if findGeocode(i) != None:

            loc = findGeocode(i)

            latitude.append(loc.latitude)
            longitude.append(loc.longitude)

        else:
            latitude.append(np.nan)
            longitude.append(np.nan)

    df["Longitude"] = longitude
    df["Latitude"] = latitude
    return df




convert_city_to_coordinates({'City':['paris', 'madrid']})

# %%
convert_city_to_coordinates({'City':['52 rue de la victoire Paris', 'madrid']})
# Out:
#                           City  Longitude   Latitude
# 0  52 rue de la victoire Paris   2.335042  48.875263
# 1                       madrid  -3.703582  40.416705

# %%
input()
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Input In [72], in <cell line: 1>()
# ----> 1 input()
#
# File ~/miniconda3/lib/python3.9/site-packages/ipykernel/kernelbase.py:1161, in Kernel.raw_input(self, prompt)
#    1157 if not self._allow_stdin:
#    1158     raise StdinNotImplementedError(
#    1159         "raw_input was called, but this frontend does not support input requests."
#    1160     )
# -> 1161 return self._input_request(
#    1162     str(prompt),
#    1163     self._parent_ident["shell"],
#    1164     self.get_parent("shell"),
#    1165     password=False,
#    1166 )
#
# File ~/miniconda3/lib/python3.9/site-packages/ipykernel/kernelbase.py:1205, in Kernel._input_request(self, prompt, ident, parent, password)
#    1202             break
#    1203 except KeyboardInterrupt:
#    1204     # re-raise KeyboardInterrupt, to truncate traceback
# ...
